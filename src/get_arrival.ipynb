# %%
from obspy import Stream , Trace
from obspy.taup import TauPyModel
from geopy.distance import geodesic

import numpy as np
import glob
import os
import time
import DasPrep as dp
import datetime
import obspy
from scipy import signal
import pandas as pd

from geopy.distance import geodesic




def  get_p_and_s_arrival_times(source_depth_in_km, distance):
    """
    **Theoretical p&s wave arrival time**
    reference page:https://docs.obspy.org/packages/obspy.taup.html
    Parameters：
    - model: 地震模型，如 "ak135" 或 "prem"
    - source_depth_in_km: event deepth（单位：千米）
    - distance_in_degree: epicenter（unit：degree）--use epicenter(km)/111
    Return：
    - P wave arrival time---travel_time_p,travel_time_s
    - S wave arrival time-travel_time_s
    """
    distance_in_degree = distance / 111

    # 创建 TauPyModel 实例
    model = TauPyModel(model="iasp91")
    # 获取 P 波到时
    travel_time_p ,travel_time_s = False , False
    try:
        arrival_p = model.get_travel_times(source_depth_in_km=source_depth_in_km,
                                           distance_in_degree=distance_in_degree,
                                           phase_list=["P", 'p'])

    except ValueError:
        arrival_p = model.get_travel_times(source_depth_in_km=source_depth_in_km,
                                           distance_in_degree=distance_in_degree,
                                           phase_list=["p"])
    if len(arrival_p)> 0:
        travel_time_p = round(arrival_p[0].time, 3)

    # 获取 S 波到时
    try:
        arrival_s = model.get_travel_times(source_depth_in_km=source_depth_in_km,
                                           distance_in_degree=distance_in_degree,
                                           phase_list=["S", 's'])
    except ValueError:
        arrival_s = model.get_travel_times(source_depth_in_km=source_depth_in_km,
                                           distance_in_degree=distance_in_degree,
                                           phase_list=["s"])

    if len(arrival_s)> 0:
        travel_time_s = round(arrival_s[0].time, 3)

    return travel_time_p, travel_time_s


theory_arrival_cat = pd.DataFrame(columns = ["travel_time_p_date", "travel_time_s_date", 'travel_time_p', 'travel_time_s' , 'Date','Time','Lat.','Lon.','Dep.','Mag.','num','station','has'])

eq_cat = pd.read_csv("/home/disk/disk01/wzm/DAS_DL_Dataset/src/202ML0_guangdongCatalog.eqt", delim_whitespace=True , encoding='gb18030' ,header=None, names=['Date','Time','Lat.','Lon.','Dep.','Mag.','num','station'] , dtype = str)

print(str(eq_cat['Date'].values[0])+' '+str(eq_cat['Time'].values[0]))
eq_time = np.array([datetime.datetime.strptime(str(eq_cat['Date'].values[i])+' '+str(eq_cat['Time'][i]), '%Y%m%d %H%M%S.%f') - datetime.timedelta(hours=8)
       for i in range(len(eq_cat))])

start_time , end_time = datetime.datetime(2024,9,21) , datetime.datetime(2024,10,21,2,19,40,357)
has_eq_window =  np.where((eq_time > start_time) & (eq_time < end_time))
# print(has_eq_window)
has_eq_cat = eq_cat.loc[has_eq_window]
# print(has_eq_cat)
for idx , event in has_eq_cat.iterrows():
    print(idx, event)
    # 定义两个坐标点
    fiber_0 = (23.929621 , 114.456382	)
    event_loc = (float(event['Lat.']), float(event['Lon.']))

    # 计算距离
    distance = geodesic(fiber_0, event_loc).km

    travel_time_p, travel_time_s = get_p_and_s_arrival_times( float(event['Dep.']),distance)
    if travel_time_p!=False : 
        print( travel_time_p, travel_time_s )
        travel_time_p_date = eq_time[idx] + datetime.timedelta(seconds=travel_time_p)
        travel_time_s_date = eq_time[idx] + datetime.timedelta(seconds=travel_time_s)
        theory_arrival_cat.loc[len(theory_arrival_cat)] = [travel_time_p_date, travel_time_s_date , travel_time_p, travel_time_s ,   event['Date'],event['Time'],event['Lat.'],event['Lon.'],event['Dep.'],event['Mag.'],event['num'],event['station'] , True]
    else:
        theory_arrival_cat.loc[len(theory_arrival_cat)] = [eq_time[idx] , eq_time[idx]  , eq_time[idx] , eq_time[idx]  ,   event['Date'],event['Time'],event['Lat.'],event['Lon.'],event['Dep.'],event['Mag.'],event['num'],event['station'] , False]


theory_arrival_cat.to_csv("/home/disk/disk01/wzm/DAS_DL_Dataset/data/xfj/theory_arrival_cat_Pp.csv",index=False,sep=',')
# Out:
# 20200101 024917.00
# 18512 Date              20240921
# Time             092816.00
# Lat.             23.318300
# Lon.            117.138000
# Dep.                   0.8
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P2.2s)
# Name: 18512, dtype: object
# 42.351 74.923
# 18513 Date              20240921
# Time             093553.00
# Lat.             23.057199
# Lon.            117.208000
# Dep.                   0.9
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P3.0s)
# Name: 18513, dtype: object
# 44.236 78.314
# 18514 Date              20240921
# Time             102228.00
# Lat.             23.195801
# Lon.            117.356003
# Dep.                   0.6
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P1.6s)
# Name: 18514, dtype: object
# 45.483 80.551
# 18515 Date         20240921
# Time        113902.00
# Lat.        23.731001
# Lon.       114.620003
# Dep.              1.2
# Mag.             8.69
# num                 0
# station          广东河源
# Name: 18515, dtype: object
# 4.771 8.236
# 18516 Date              20240921
# Time             122454.00
# Lat.             23.195601
# Lon.            117.420998
# Dep.                   0.6
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P2.2s)
# Name: 18516, dtype: object
# 46.277 81.979
# 18517 Date              20240921
# Time             132115.00
# Lat.             23.114901
# Lon.            117.287003
# Dep.                   0.0
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P2.2s)
# Name: 18517, dtype: object
# 45.04 79.744
# 18518 Date              20240921
# Time             145142.00
# Lat.             23.245501
# Lon.            117.474998
# Dep.                   0.3
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P2.6s)
# Name: 18518, dtype: object
# 46.797 82.909
# 18519 Date         20240921
# Time        161517.00
# Lat.        22.948000
# Lon.       115.513000
# Dep.              2.3
# Mag.            12.78
# num                 0
# station          广东陆丰
# Name: 18519, dtype: object
# 26.229 45.677
# 18520 Date              20240921
# Time             190027.00
# Lat.             23.264299
# Lon.            117.355003
# Dep.                   0.4
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P1.5s)
# Name: 18520, dtype: object
# 45.248 80.124
# 18521 Date              20240921
# Time             214157.00
# Lat.             23.009300
# Lon.            117.311996
# Dep.                   0.4
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P3.4s)
# Name: 18521, dtype: object
# 45.761 81.047
# 18522 Date         20240922
# Time        052341.00
# Lat.        23.729000
# Lon.       114.749001
# Dep.              0.1
# Mag.            11.54
# num                 0
# station          广东紫金
# Name: 18522, dtype: object
# 6.423 11.086
# 18523 Date         20240922
# Time        061626.00
# Lat.        23.718000
# Lon.       114.668999
# Dep.              0.3
# Mag.             7.85
# num                 0
# station          广东河源
# Name: 18523, dtype: object
# 5.513 9.516
# 18524 Date         20240922
# Time        194949.00
# Lat.        23.719000
# Lon.       114.684998
# Dep.              0.3
# Mag.             3.45
# num                 0
# station          广东河源
# Name: 18524, dtype: object
# 5.694 9.829
# 18525 Date         20240922
# Time        203411.00
# Lat.        21.732000
# Lon.       111.805000
# Dep.              1.2
# Mag.            10.52
# num                 0
# station          广东阳江
# Name: 18525, dtype: object
# 52.609 93.378
# 18526 Date         20240923
# Time        001959.00
# Lat.        23.294001
# Lon.       117.367996
# Dep.              1.4
# Mag.            13.89
# num                 0
# station        广东南澳海域
# Name: 18526, dtype: object
# 45.187 80.033
# 18527 Date              20240923
# Time             022413.00
# Lat.             23.368799
# Lon.            117.263000
# Dep.                   0.5
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P1.8s)
# Name: 18527, dtype: object
# 43.764 77.457
# 18528 Date              20240923
# Time             060117.00
# Lat.             23.295200
# Lon.            117.397003
# Dep.                   0.3
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P1.8s)
# Name: 18528, dtype: object
# 45.672 80.886
# 18529 Date              20240923
# Time             112717.00
# Lat.             23.341600
# Lon.            117.111000
# Dep.                   0.7
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P2.6s)
# Name: 18529, dtype: object
# 41.953 74.205
# 18530 Date         20240923
# Time        113819.00
# Lat.        23.291000
# Lon.       117.325996
# Dep.              1.0
# Mag.            23.33
# num                 0
# station        广东南澳海域
# Name: 18530, dtype: object
# 44.728 79.202
# 18531 Date         20240923
# Time        114859.00
# Lat.        23.285999
# Lon.       117.322998
# Dep.              0.4
# Mag.            23.72
# num                 0
# station        广东南澳海域
# Name: 18531, dtype: object
# 44.781 79.284
# 18532 Date         20240923
# Time        123202.00
# Lat.        23.289000
# Lon.       117.325996
# Dep.              0.9
# Mag.            23.68
# num                 0
# station        广东南澳海域
# Name: 18532, dtype: object
# 44.747 79.233
# 18533 Date         20240923
# Time        130846.00
# Lat.        23.290001
# Lon.       117.320000
# Dep.              1.3
# Mag.            23.80
# num                 0
# station        广东南澳海域
# Name: 18533, dtype: object
# 44.622 79.016
# 18534 Date         20240923
# Time        164816.00
# Lat.        23.288000
# Lon.       117.321999
# Dep.              1.3
# Mag.            23.74
# num                 0
# station        广东南澳海域
# Name: 18534, dtype: object
# 44.653 79.072
# 18535 Date              20240924
# Time             173251.00
# Lat.             23.185101
# Lon.            117.378998
# Dep.                   0.5
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P1.9s)
# Name: 18535, dtype: object
# 45.816 81.148
# 18536 Date              20240924
# Time             195946.00
# Lat.             23.229500
# Lon.            117.271004
# Dep.                   0.4
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P1.3s)
# Name: 18536, dtype: object
# 44.344 78.499
# 18537 Date              20240924
# Time             215218.00
# Lat.             23.161501
# Lon.            117.330002
# Dep.                   0.4
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P1.8s)
# Name: 18537, dtype: object
# 45.323 80.259
# 18538 Date         20240924
# Time        222959.00
# Lat.        23.909000
# Lon.       114.485001
# Dep.              0.2
# Mag.             7.87
# num                 0
# station          广东东源
# Name: 18538, dtype: object
# 0.64 1.105
# 18539 Date         20240925
# Time        005657.00
# Lat.        23.215000
# Lon.       117.272003
# Dep.              0.7
# Mag.            10.45
# num                 0
# station        广东南澳海域
# Name: 18539, dtype: object
# 44.374 78.559
# 18540 Date         20240925
# Time        010212.00
# Lat.        23.150999
# Lon.       117.266998
# Dep.              0.2
# Mag.            14.70
# num                 0
# station        广东南澳海域
# Name: 18540, dtype: object
# 44.625 79.0
# 18541 Date              20240925
# Time             021141.00
# Lat.             23.448299
# Lon.            117.237000
# Dep.                   0.1
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P2.8s)
# Name: 18541, dtype: object
# 43.263 76.549
# 18542 Date              20240925
# Time             021253.00
# Lat.             23.278500
# Lon.            117.069000
# Dep.                   0.0
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P2.8s)
# Name: 18542, dtype: object
# 41.745 73.817
# 18543 Date              20240925
# Time             021543.00
# Lat.             23.382601
# Lon.            117.445999
# Dep.                   0.1
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P2.8s)
# Name: 18543, dtype: object
# 46.036 81.536
# 18544 Date         20240925
# Time        041834.00
# Lat.        20.850000
# Lon.       112.322998
# Dep.              2.1
# Mag.             9.73
# num                 0
# station            南海
# Name: 18544, dtype: object
# 57.525 102.233
# 18545 Date             20240925
# Time            100213.00
# Lat.            21.721901
# Lon.           111.862999
# Dep.                  0.7
# Mag.                -1.00
# num                     0
# station    广东阳江台(S-P2.1s)
# Name: 18545, dtype: object
# 52.217 92.663
# 18546 Date              20240925
# Time             105734.00
# Lat.             23.151400
# Lon.            117.230003
# Dep.                   0.5
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P1.9s)
# Name: 18546, dtype: object
# 44.139 78.132
# 18547 Date              20240925
# Time             110838.00
# Lat.             23.177401
# Lon.            117.238998
# Dep.                   0.6
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P1.6s)
# Name: 18547, dtype: object
# 44.131 78.119
# 18548 Date              20240925
# Time             144707.00
# Lat.             23.375000
# Lon.            117.262001
# Dep.                   0.3
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P1.9s)
# Name: 18548, dtype: object
# 43.757 77.441
# 18549 Date              20240925
# Time             154633.00
# Lat.             23.435499
# Lon.            117.356003
# Dep.                   0.6
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P2.7s)
# Name: 18549, dtype: object
# 44.715 79.17
# 18550 Date              20240925
# Time             184000.00
# Lat.             23.212200
# Lon.            117.338997
# Dep.                   0.5
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P1.5s)
# Name: 18550, dtype: object
# 45.226 80.087
# 18551 Date              20240925
# Time             193159.00
# Lat.             23.378300
# Lon.            117.325996
# Dep.                   0.3
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P2.0s)
# Name: 18551, dtype: object
# 44.538 78.846
# 18552 Date         20240926
# Time        025932.00
# Lat.        23.716999
# Lon.       114.668999
# Dep.              0.2
# Mag.             8.07
# num                 0
# station          广东河源
# Name: 18552, dtype: object
# 5.526 9.54
# 18553 Date              20240926
# Time             045220.00
# Lat.             23.199800
# Lon.            117.492996
# Dep.                   0.2
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P2.8s)
# Name: 18553, dtype: object
# 47.19 83.614
# 18554 Date         20240926
# Time        084452.00
# Lat.        23.923000
# Lon.       114.469002
# Dep.              0.3
# Mag.             8.33
# num                 0
# station          广东东源
# Name: 18554, dtype: object
# 0.261 0.45
# 18555 Date         20240926
# Time        111137.00
# Lat.        23.900000
# Lon.       114.498001
# Dep.              0.3
# Mag.             7.53
# num                 0
# station          广东东源
# Name: 18555, dtype: object
# 0.927 1.6
# 18556 Date         20240926
# Time        111947.00
# Lat.        23.312000
# Lon.       117.365997
# Dep.              0.8
# Mag.            13.86
# num                 0
# station        广东南澳海域
# Name: 18556, dtype: object
# 45.176 80.002
# 18557 Date              20240926
# Time             111958.00
# Lat.             23.256901
# Lon.            117.422997
# Dep.                   0.0
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P2.0s)
# Name: 18557, dtype: object
# 46.156 81.75
# 18558 Date             20240926
# Time            112925.00
# Lat.            21.759600
# Lon.           111.797997
# Dep.                  0.5
# Mag.                -1.00
# num                     0
# station    广东阳江台(S-P2.3s)
# Name: 18558, dtype: object
# 52.506 93.179
# 18559 Date              20240926
# Time             115243.00
# Lat.             23.206600
# Lon.            117.137001
# Dep.                   0.1
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P2.2s)
# Name: 18559, dtype: object
# 42.836 75.782
# 18560 Date         20240926
# Time        160357.00
# Lat.        23.780001
# Lon.       114.599998
# Dep.              0.1
# Mag.             9.91
# num                 0
# station          广东东源
# Name: 18560, dtype: object
# 3.818 6.59
# 18561 Date              20240926
# Time             225951.00
# Lat.             23.341700
# Lon.            117.156998
# Dep.                   0.3
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P2.2s)
# Name: 18561, dtype: object
# 42.566 75.3
# 18562 Date         20240926
# Time        233856.00
# Lat.        23.891001
# Lon.       114.408997
# Dep.              0.9
# Mag.            10.12
# num                 0
# station          广东东源
# Name: 18562, dtype: object
# 1.124 1.941
# 18563 Date              20240927
# Time             011242.00
# Lat.             23.277599
# Lon.            117.421997
# Dep.                   0.4
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P2.0s)
# Name: 18563, dtype: object
# 46.026 81.523
# 18564 Date         20240927
# Time        031357.00
# Lat.        23.294001
# Lon.       117.337997
# Dep.              0.6
# Mag.            17.40
# num                 0
# station        广东南澳海域
# Name: 18564, dtype: object
# 44.914 79.528
# 18565 Date         20240927
# Time        044947.00
# Lat.        21.861000
# Lon.       111.752998
# Dep.              0.5
# Mag.            12.31
# num                 0
# station          广东阳西
# Name: 18565, dtype: object
# 52.029 92.322
# 18566 Date         20240927
# Time        064635.00
# Lat.        22.986000
# Lon.       117.862000
# Dep.              1.5
# Mag.            11.31
# num                 0
# station            南海
# Name: 18566, dtype: object
# 52.353 92.922
# 18567 Date              20240927
# Time             071802.00
# Lat.             23.222200
# Lon.            117.244003
# Dep.                   0.7
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P1.4s)
# Name: 18567, dtype: object
# 44.006 77.896
# 18568 Date         20240927
# Time        073940.00
# Lat.        23.833000
# Lon.       114.514999
# Dep.              0.3
# Mag.             9.03
# num                 0
# station          广东东源
# Name: 18568, dtype: object
# 2.117 3.654
# 18569 Date         20240927
# Time        080801.00
# Lat.        23.295000
# Lon.       117.141998
# Dep.              0.4
# Mag.             7.34
# num                 0
# station        广东南澳海域
# Name: 18569, dtype: object
# 42.529 75.236
# 18570 Date         20240927
# Time        105140.00
# Lat.        20.858000
# Lon.       112.286003
# Dep.              2.1
# Mag.             7.05
# num                 0
# station            南海
# Name: 18570, dtype: object
# 57.69 102.53
# 18571 Date         20240927
# Time        123658.00
# Lat.        23.316999
# Lon.       117.431000
# Dep.              0.5
# Mag.            14.19
# num                 0
# station        广东南澳海域
# Name: 18571, dtype: object
# 45.997 81.474
# 18572 Date              20240927
# Time             171506.00
# Lat.             23.310499
# Lon.            117.156998
# Dep.                   0.3
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P2.0s)
# Name: 18572, dtype: object
# 42.671 75.489
# 18573 Date              20240927
# Time             223040.00
# Lat.             23.304100
# Lon.            117.250000
# Dep.                   0.0
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P1.4s)
# Name: 18573, dtype: object
# 43.871 77.641
# 18574 Date              20240928
# Time             014718.00
# Lat.             23.134001
# Lon.            117.313004
# Dep.                   0.2
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P2.0s)
# Name: 18574, dtype: object
# 45.251 80.127
# 18575 Date         20240928
# Time        195044.00
# Lat.        23.194000
# Lon.       113.678001
# Dep.              0.9
# Mag.             8.52
# num                 0
# station          广东增城
# Name: 18575, dtype: object
# 19.656 33.93
# 18576 Date         20240928
# Time        233107.00
# Lat.        23.730000
# Lon.       114.627998
# Dep.              0.7
# Mag.             8.54
# num                 0
# station          广东河源
# Name: 18576, dtype: object
# 4.87 8.406
# 18577 Date         20240928
# Time        233134.00
# Lat.        23.729000
# Lon.       114.629997
# Dep.              0.8
# Mag.             8.42
# num                 0
# station          广东河源
# Name: 18577, dtype: object
# 4.907 8.47
# 18578 Date         20240929
# Time        021043.00
# Lat.        23.731001
# Lon.       114.627998
# Dep.              0.1
# Mag.             8.35
# num                 0
# station          广东河源
# Name: 18578, dtype: object
# 4.853 8.378
# 18579 Date         20240929
# Time        071912.00
# Lat.        24.653000
# Lon.       116.495003
# Dep.              0.8
# Mag.            10.56
# num                 0
# station          广东梅州
# Name: 18579, dtype: object
# 34.922 61.561
# 18580 Date         20240929
# Time        091118.00
# Lat.        23.285999
# Lon.       117.333000
# Dep.              1.0
# Mag.            15.78
# num                 0
# station        广东南澳海域
# Name: 18580, dtype: object
# 44.831 79.387
# 18581 Date         20240929
# Time        091542.00
# Lat.        21.730000
# Lon.       111.795998
# Dep.              1.1
# Mag.             5.17
# num                 0
# station          广东阳江
# Name: 18581, dtype: object
# 52.725 93.584
# 18582 Date         20240929
# Time        101428.00
# Lat.        23.764999
# Lon.       114.597000
# Dep.              0.1
# Mag.             6.49
# num                 0
# station          广东东源
# Name: 18582, dtype: object
# 4.005 6.913
# 18583 Date         20240929
# Time        102313.00
# Lat.        23.764999
# Lon.       114.597000
# Dep.              0.2
# Mag.             6.50
# num                 0
# station          广东东源
# Name: 18583, dtype: object
# 4.005 6.913
# 18584 Date         20240929
# Time        105654.00
# Lat.        25.004999
# Lon.       113.249001
# Dep.              0.9
# Mag.             7.88
# num                 0
# station          广东乳源
# Name: 18584, dtype: object
# 28.574 50.145
# 18585 Date         20240929
# Time        211916.00
# Lat.        24.396000
# Lon.       116.725998
# Dep.              1.9
# Mag.             9.94
# num                 0
# station          广东大埔
# Name: 18585, dtype: object
# 36.577 64.558
# 18586 Date         20240929
# Time        225322.00
# Lat.        23.726999
# Lon.       114.666000
# Dep.              0.7
# Mag.             9.51
# num                 0
# station          广东河源
# Name: 18586, dtype: object
# 5.352 9.238
# 18587 Date         20240930
# Time        020220.00
# Lat.        23.773001
# Lon.       114.538002
# Dep.              1.4
# Mag.             3.74
# num                 0
# station          广东东源
# Name: 18587, dtype: object
# 3.331 5.75
# 18588 Date              20240930
# Time             021001.00
# Lat.             23.266399
# Lon.            117.406998
# Dep.                   0.2
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P1.5s)
# Name: 18588, dtype: object
# 45.903 81.299
# 18589 Date         20240930
# Time        024308.00
# Lat.        21.705000
# Lon.       111.772003
# Dep.              1.0
# Mag.             8.33
# num                 0
# station          广东阳西
# Name: 18589, dtype: object
# 53.195 94.428
# 18590 Date         20240930
# Time        074545.00
# Lat.        22.385000
# Lon.       113.848000
# Dep.              1.0
# Mag.            13.18
# num                 0
# station        广东珠海海域
# Name: 18590, dtype: object
# 29.957 52.634
# 18591 Date             20240930
# Time            143338.00
# Lat.            21.853201
# Lon.           112.171997
# Dep.                  0.3
# Mag.                -1.00
# num                     0
# station    广东阳江台(S-P2.7s)
# Name: 18591, dtype: object
# 48.165 85.369
# 18592 Date              20240930
# Time             151942.00
# Lat.             23.242901
# Lon.            117.344002
# Dep.                   0.2
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P1.0s)
# Name: 18592, dtype: object
# 45.212 80.056
# 18593 Date         20240930
# Time        183548.00
# Lat.        23.721001
# Lon.       114.640999
# Dep.              1.9
# Mag.            10.80
# num                 0
# station          广东河源
# Name: 18593, dtype: object
# 5.156 8.9
# 18594 Date         20240930
# Time        184541.00
# Lat.        23.721001
# Lon.       114.640999
# Dep.              0.5
# Mag.            10.97
# num                 0
# station          广东河源
# Name: 18594, dtype: object
# 5.147 8.884
# 18595 Date         20240930
# Time        201134.00
# Lat.        23.759001
# Lon.       114.550003
# Dep.              0.3
# Mag.             5.43
# num                 0
# station          广东东源
# Name: 18595, dtype: object
# 3.656 6.311
# 18596 Date              20240930
# Time             224414.00
# Lat.             23.266899
# Lon.            117.314003
# Dep.                   0.7
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P1.3s)
# Name: 18596, dtype: object
# 44.7 79.144
# 18597 Date         20241001
# Time        004830.00
# Lat.        20.843000
# Lon.       112.328003
# Dep.              1.6
# Mag.             6.45
# num                 0
# station            南海
# Name: 18597, dtype: object
# 57.632 102.416
# 18598 Date         20241001
# Time        031456.00
# Lat.        23.231001
# Lon.       117.262001
# Dep.              1.4
# Mag.            11.28
# num                 0
# station        广东南澳海域
# Name: 18598, dtype: object
# 44.108 78.094
# 18599 Date              20241001
# Time             101630.00
# Lat.             23.427601
# Lon.            117.248001
# Dep.                   0.6
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P2.3s)
# Name: 18599, dtype: object
# 43.395 76.797
# 18600 Date         20241001
# Time        120707.00
# Lat.        23.862000
# Lon.       114.499001
# Dep.              0.4
# Mag.             8.23
# num                 0
# station          广东东源
# Name: 18600, dtype: object
# 1.497 2.583
# 18601 Date         20241001
# Time        120749.00
# Lat.        23.862000
# Lon.       114.500000
# Dep.              0.3
# Mag.             8.16
# num                 0
# station          广东东源
# Name: 18601, dtype: object
# 1.505 2.598
# 18602 Date         20241001
# Time        124321.00
# Lat.        23.249001
# Lon.       117.261002
# Dep.              1.3
# Mag.            11.87
# num                 0
# station        广东南澳海域
# Name: 18602, dtype: object
# 44.042 77.973
# 18603 Date              20241001
# Time             151008.00
# Lat.             23.326900
# Lon.            117.180000
# Dep.                   0.8
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P1.6s)
# Name: 18603, dtype: object
# 42.838 75.798
# 18604 Date              20241001
# Time             152153.00
# Lat.             23.228600
# Lon.            117.226997
# Dep.                   1.1
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P1.0s)
# Name: 18604, dtype: object
# 43.726 77.401
# 18605 Date         20241002
# Time        024929.00
# Lat.        25.037001
# Lon.       112.355003
# Dep.              2.1
# Mag.             5.04
# num                 0
# station          广东连州
# Name: 18605, dtype: object
# 37.723 66.623
# 18606 Date         20241002
# Time        054752.00
# Lat.        21.716999
# Lon.       111.831001
# Dep.              0.7
# Mag.             8.19
# num                 0
# station          广东阳江
# Name: 18606, dtype: object
# 52.563 93.285
# 18607 Date             20241002
# Time            054805.00
# Lat.            21.701900
# Lon.           112.055000
# Dep.                  0.4
# Mag.                -1.00
# num                     0
# station    广东阳江台(S-P2.4s)
# Name: 18607, dtype: object
# 50.682 89.897
# 18608 Date             20241002
# Time            061514.00
# Lat.            21.770300
# Lon.           111.781998
# Dep.                  0.4
# Mag.                -1.00
# num                     0
# station    广东阳江台(S-P2.4s)
# Name: 18608, dtype: object
# 52.574 93.299
# 18609 Date         20241002
# Time        212655.00
# Lat.        23.830999
# Lon.       114.514000
# Dep.              0.9
# Mag.             8.90
# num                 0
# station          广东东源
# Name: 18609, dtype: object
# 2.147 3.706
# 18610 Date         20241003
# Time        142802.00
# Lat.        23.764999
# Lon.       114.596001
# Dep.              0.2
# Mag.             6.37
# num                 0
# station          广东东源
# Name: 18610, dtype: object
# 3.994 6.894
# 18611 Date         20241003
# Time        224554.00
# Lat.        23.193001
# Lon.       117.283997
# Dep.              1.0
# Mag.            13.30
# num                 0
# station        广东南澳海域
# Name: 18611, dtype: object
# 44.568 78.913
# 18612 Date              20241003
# Time             232341.00
# Lat.             23.190901
# Lon.            117.413002
# Dep.                   0.8
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P1.8s)
# Name: 18612, dtype: object
# 46.173 81.795
# 18613 Date         20241004
# Time        052756.00
# Lat.        23.730000
# Lon.       114.623001
# Dep.              0.3
# Mag.             8.85
# num                 0
# station          广东河源
# Name: 18613, dtype: object
# 4.815 8.311
# 18614 Date              20241004
# Time             083727.00
# Lat.             23.351500
# Lon.            117.431000
# Dep.                   0.6
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P2.2s)
# Name: 18614, dtype: object
# 45.88 81.265
# 18615 Date         20241004
# Time        145206.00
# Lat.        21.742001
# Lon.       111.754997
# Dep.              1.0
# Mag.            10.05
# num                 0
# station          广东阳西
# Name: 18615, dtype: object
# 53.018 94.109
# 18616 Date         20241004
# Time        165320.00
# Lat.        23.278999
# Lon.       117.309998
# Dep.              1.0
# Mag.            14.08
# num                 0
# station        广东南澳海域
# Name: 18616, dtype: object
# 44.573 78.921
# 18617 Date         20241004
# Time        174400.00
# Lat.        23.860001
# Lon.       114.499001
# Dep.              0.4
# Mag.             8.96
# num                 0
# station          广东东源
# Name: 18617, dtype: object
# 1.53 2.641
# 18618 Date              20241005
# Time             062040.00
# Lat.             23.146900
# Lon.            117.237999
# Dep.                   0.7
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P1.6s)
# Name: 18618, dtype: object
# 44.23 78.3
# 18619 Date              20241005
# Time             065748.00
# Lat.             23.009501
# Lon.            117.311996
# Dep.                   0.9
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P3.3s)
# Name: 18619, dtype: object
# 45.7 80.947
# 18620 Date              20241005
# Time             103135.00
# Lat.             23.332800
# Lon.            117.392998
# Dep.                   1.0
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P1.7s)
# Name: 18620, dtype: object
# 45.419 80.444
# 18621 Date              20241005
# Time             192056.00
# Lat.             23.280300
# Lon.            117.362000
# Dep.                   0.8
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P1.1s)
# Name: 18621, dtype: object
# 45.231 80.101
# 18622 Date         20241005
# Time        210545.00
# Lat.        20.851000
# Lon.       112.311996
# Dep.              3.1
# Mag.            21.23
# num                 0
# station            南海
# Name: 18622, dtype: object
# 57.469 102.151
# 18623 Date         20241006
# Time        074641.00
# Lat.        23.718000
# Lon.       114.608002
# Dep.              1.0
# Mag.             9.17
# num                 0
# station          广东河源
# Name: 18623, dtype: object
# 4.851 8.374
# 18624 Date         20241006
# Time        131536.00
# Lat.        23.763000
# Lon.       114.619003
# Dep.              0.3
# Mag.             9.00
# num                 0
# station          广东河源
# Name: 18624, dtype: object
# 4.283 7.394
# 18625 Date         20241006
# Time        153019.00
# Lat.        24.114000
# Lon.       112.966003
# Dep.              1.4
# Mag.            12.80
# num                 0
# station          广东英德
# Name: 18625, dtype: object
# 26.308 45.609
# 18626 Date              20241007
# Time             020326.00
# Lat.             23.149000
# Lon.            117.332001
# Dep.                   0.8
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P1.9s)
# Name: 18626, dtype: object
# 45.349 80.313
# 18627 Date         20241007
# Time        021657.00
# Lat.        23.285999
# Lon.       117.115997
# Dep.              1.8
# Mag.            11.03
# num                 0
# station        广东南澳海域
# Name: 18627, dtype: object
# 42.075 74.444
# 18628 Date         20241007
# Time        061524.00
# Lat.        24.377001
# Lon.       116.227997
# Dep.              0.8
# Mag.             7.92
# num                 0
# station          广东梅州
# Name: 18628, dtype: object
# 30.562 53.719
# 18629 Date              20241007
# Time             145535.00
# Lat.             23.126499
# Lon.            117.299004
# Dep.                   0.2
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P2.1s)
# Name: 18629, dtype: object
# 45.113 79.878
# 18630 Date         20241007
# Time        175427.00
# Lat.        23.716000
# Lon.       114.712997
# Dep.              0.2
# Mag.             7.45
# num                 0
# station          广东河源
# Name: 18630, dtype: object
# 6.09 10.513
# 18631 Date         20241007
# Time        204215.00
# Lat.        23.305000
# Lon.       117.403000
# Dep.              0.9
# Mag.            13.66
# num                 0
# station        广东南澳海域
# Name: 18631, dtype: object
# 45.642 80.843
# 18632 Date              20241007
# Time             210953.00
# Lat.             23.307800
# Lon.            117.413002
# Dep.                   0.3
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P2.0s)
# Name: 18632, dtype: object
# 45.828 81.167
# 18633 Date         20241008
# Time        050943.00
# Lat.        23.743999
# Lon.       114.720001
# Dep.              0.1
# Mag.            10.66
# num                 0
# station          广东河源
# Name: 18633, dtype: object
# 5.842 10.084
# 18634 Date         20241008
# Time        072008.00
# Lat.        23.743000
# Lon.       114.720001
# Dep.              0.2
# Mag.            10.85
# num                 0
# station          广东河源
# Name: 18634, dtype: object
# 5.853 10.104
# 18635 Date         20241008
# Time        080147.00
# Lat.        23.749001
# Lon.       114.636002
# Dep.              0.3
# Mag.            10.86
# num                 0
# station          广东河源
# Name: 18635, dtype: object
# 4.683 8.083
# 18636 Date         20241008
# Time        082526.00
# Lat.        23.746000
# Lon.       114.721001
# Dep.              0.1
# Mag.            10.53
# num                 0
# station          广东河源
# Name: 18636, dtype: object
# 5.832 10.068
# 18637 Date         20241008
# Time        083047.00
# Lat.        23.743000
# Lon.       114.720001
# Dep.              0.1
# Mag.            10.71
# num                 0
# station          广东河源
# Name: 18637, dtype: object
# 5.853 10.104
# 18638 Date         20241008
# Time        083043.00
# Lat.        23.745001
# Lon.       114.721001
# Dep.              0.1
# Mag.            10.16
# num                 0
# station          广东河源
# Name: 18638, dtype: object
# 5.844 10.088
# 18639 Date         20241008
# Time        083111.00
# Lat.        23.745001
# Lon.       114.721001
# Dep.              0.2
# Mag.            10.33
# num                 0
# station          广东河源
# Name: 18639, dtype: object
# 5.844 10.088
# 18640 Date              20241008
# Time             090945.00
# Lat.             23.345501
# Lon.            117.316002
# Dep.                   0.3
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P1.6s)
# Name: 18640, dtype: object
# 44.513 78.802
# 18641 Date              20241008
# Time             143127.00
# Lat.             23.266199
# Lon.            117.259003
# Dep.                   0.9
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P1.2s)
# Name: 18641, dtype: object
# 44.004 77.897
# 18642 Date         20241008
# Time        144600.00
# Lat.        23.745001
# Lon.       114.720001
# Dep.              0.1
# Mag.            10.55
# num                 0
# station          广东河源
# Name: 18642, dtype: object
# 5.83 10.064
# 18643 Date         20241009
# Time        010904.00
# Lat.        21.739000
# Lon.       111.797997
# Dep.              1.0
# Mag.            10.43
# num                 0
# station          广东阳江
# Name: 18643, dtype: object
# 52.635 93.421
# 18644 Date         20241009
# Time        014152.00
# Lat.        23.913000
# Lon.       114.476997
# Dep.              0.3
# Mag.             7.96
# num                 0
# station          广东东源
# Name: 18644, dtype: object
# 0.485 0.837
# 18645 Date         20241009
# Time        052005.00
# Lat.        23.669001
# Lon.       112.956001
# Dep.              1.4
# Mag.            14.68
# num                 0
# station          广东清新
# Name: 18645, dtype: object
# 26.632 46.387
# 18646 Date         20241009
# Time        082015.00
# Lat.        23.750000
# Lon.       114.633003
# Dep.              1.9
# Mag.            10.56
# num                 0
# station          广东河源
# Name: 18646, dtype: object
# 4.644 8.016
# 18647 Date              20241009
# Time             134335.00
# Lat.             23.212999
# Lon.            117.404999
# Dep.                   0.7
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P2.0s)
# Name: 18647, dtype: object
# 46.006 81.493
# 18648 Date         20241009
# Time        191650.00
# Lat.        23.914000
# Lon.       114.476997
# Dep.              0.7
# Mag.             9.53
# num                 0
# station          广东东源
# Name: 18648, dtype: object
# 0.485 0.837
# 18649 Date         20241010
# Time        023034.00
# Lat.        22.325001
# Lon.       111.482002
# Dep.              1.7
# Mag.            13.19
# num                 0
# station          广东阳春
# Name: 18649, dtype: object
# 51.012 90.515
# 18650 Date         20241010
# Time        031355.00
# Lat.        23.757999
# Lon.       114.561996
# Dep.              0.3
# Mag.             6.24
# num                 0
# station          广东东源
# Name: 18650, dtype: object
# 3.773 6.512
# 18651 Date              20241010
# Time             062623.00
# Lat.             23.386999
# Lon.            117.237999
# Dep.                   0.4
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P2.1s)
# Name: 18651, dtype: object
# 43.412 76.823
# 18652 Date         20241010
# Time        101246.00
# Lat.        23.271999
# Lon.       117.278000
# Dep.              1.2
# Mag.            17.08
# num                 0
# station        广东南澳海域
# Name: 18652, dtype: object
# 44.18 78.22
# 18653 Date             20241010
# Time            110544.00
# Lat.            21.715799
# Lon.           111.799004
# Dep.                  0.4
# Mag.                -1.00
# num                     0
# station    广东阳江台(S-P2.7s)
# Name: 18653, dtype: object
# 52.912 93.907
# 18654 Date             20241010
# Time            110942.00
# Lat.            21.703400
# Lon.           111.804001
# Dep.                  0.4
# Mag.                -1.00
# num                     0
# station    广东阳江台(S-P2.8s)
# Name: 18654, dtype: object
# 52.98 94.029
# 18655 Date         20241010
# Time        143541.00
# Lat.        23.283001
# Lon.       117.290001
# Dep.              1.0
# Mag.            16.05
# num                 0
# station        广东南澳海域
# Name: 18655, dtype: object
# 44.314 78.455
# 18656 Date         20241010
# Time        185650.00
# Lat.        23.724001
# Lon.       114.693001
# Dep.              0.6
# Mag.             9.34
# num                 0
# station          广东河源
# Name: 18656, dtype: object
# 5.729 9.889
# 18657 Date         20241011
# Time        033624.00
# Lat.        21.864000
# Lon.       111.700996
# Dep.              0.4
# Mag.             5.40
# num                 0
# station          广东阳西
# Name: 18657, dtype: object
# 52.527 93.214
# 18658 Date         20241011
# Time        083337.00
# Lat.        23.728001
# Lon.       114.624001
# Dep.              0.3
# Mag.             9.03
# num                 0
# station          广东河源
# Name: 18658, dtype: object
# 4.856 8.382
# 18659 Date         20241011
# Time        091643.00
# Lat.        23.726999
# Lon.       114.624001
# Dep.              0.1
# Mag.             8.17
# num                 0
# station          广东河源
# Name: 18659, dtype: object
# 4.871 8.408
# 18660 Date         20241011
# Time        115343.00
# Lat.        23.729000
# Lon.       114.621002
# Dep.              0.1
# Mag.             9.15
# num                 0
# station          广东河源
# Name: 18660, dtype: object
# 4.808 8.3
# 18661 Date         20241011
# Time        210520.00
# Lat.        23.249001
# Lon.       117.106003
# Dep.              0.4
# Mag.             6.06
# num                 0
# station        广东南澳海域
# Name: 18661, dtype: object
# 42.258 74.748
# 18662 Date              20241011
# Time             221400.00
# Lat.             23.336201
# Lon.            117.431000
# Dep.                   0.6
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P2.3s)
# Name: 18662, dtype: object
# 45.926 81.348
# 18663 Date         20241011
# Time        230054.00
# Lat.        23.233000
# Lon.       117.297997
# Dep.              0.8
# Mag.            11.02
# num                 0
# station        广东南澳海域
# Name: 18663, dtype: object
# 44.613 78.99
# 18664 Date         20241012
# Time        000657.00
# Lat.        20.864000
# Lon.       112.292999
# Dep.              2.0
# Mag.            11.34
# num                 0
# station            南海
# Name: 18664, dtype: object
# 57.584 102.337
# 18665 Date         20241012
# Time        035233.00
# Lat.        24.031000
# Lon.       112.571999
# Dep.              0.8
# Mag.             7.25
# num                 0
# station          广东清新
# Name: 18665, dtype: object
# 31.226 54.912
# 18666 Date         20241012
# Time        081704.00
# Lat.        23.719999
# Lon.       114.630997
# Dep.              0.3
# Mag.             7.84
# num                 0
# station          广东河源
# Name: 18666, dtype: object
# 5.052 8.721
# 18667 Date         20241012
# Time        092508.00
# Lat.        23.363001
# Lon.       117.179001
# Dep.              0.8
# Mag.             7.46
# num                 0
# station        广东南澳海域
# Name: 18667, dtype: object
# 42.709 75.566
# 18668 Date         20241012
# Time        160508.00
# Lat.        23.728001
# Lon.       114.619003
# Dep.              0.9
# Mag.             8.98
# num                 0
# station          广东河源
# Name: 18668, dtype: object
# 4.805 8.294
# 18669 Date         20241013
# Time        105357.00
# Lat.        24.403000
# Lon.       116.733002
# Dep.              1.8
# Mag.            17.76
# num                 0
# station          广东大埔
# Name: 18669, dtype: object
# 36.696 64.77
# 18670 Date         20241013
# Time        123617.00
# Lat.        20.826000
# Lon.       112.296997
# Dep.              2.5
# Mag.            16.88
# num                 0
# station            南海
# Name: 18670, dtype: object
# 57.934 102.977
# 18671 Date         20241013
# Time        130103.00
# Lat.        21.738001
# Lon.       111.783997
# Dep.              0.5
# Mag.             6.12
# num                 0
# station          广东阳西
# Name: 18671, dtype: object
# 52.838 93.776
# 18672 Date              20241013
# Time             183920.00
# Lat.             23.146601
# Lon.            117.319000
# Dep.                   0.4
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P1.9s)
# Name: 18672, dtype: object
# 45.249 80.126
# 18673 Date         20241014
# Time        015624.00
# Lat.        21.702000
# Lon.       111.769997
# Dep.              0.6
# Mag.             4.16
# num                 0
# station          广东阳西
# Name: 18673, dtype: object
# 53.29 94.591
# 18674 Date         20241014
# Time        044347.00
# Lat.        21.764999
# Lon.       111.896004
# Dep.              1.6
# Mag.            11.36
# num                 0
# station          广东阳江
# Name: 18674, dtype: object
# 51.396 91.204
# 18675 Date         20241014
# Time        123701.00
# Lat.        23.474001
# Lon.       115.374001
# Dep.              2.4
# Mag.             9.30
# num                 0
# station          广东紫金
# Name: 18675, dtype: object
# 18.364 31.7
# 18676 Date         20241014
# Time        144832.00
# Lat.        23.218000
# Lon.       117.253998
# Dep.              0.8
# Mag.            14.15
# num                 0
# station        广东南澳海域
# Name: 18676, dtype: object
# 44.131 78.124
# 18677 Date         20241014
# Time        145055.00
# Lat.        23.158001
# Lon.       117.209000
# Dep.              0.9
# Mag.             6.95
# num                 0
# station        广东南澳海域
# Name: 18677, dtype: object
# 43.81 77.547
# 18678 Date             20241014
# Time            174811.00
# Lat.            21.717600
# Lon.           111.907997
# Dep.                  0.4
# Mag.                -1.00
# num                     0
# station    广东阳江台(S-P2.0s)
# Name: 18678, dtype: object
# 51.874 92.041
# 18679 Date             20241014
# Time            183309.00
# Lat.            21.678200
# Lon.           111.839996
# Dep.                  0.3
# Mag.                -1.00
# num                     0
# station    广东阳江台(S-P2.8s)
# Name: 18679, dtype: object
# 52.89 93.866
# 18680 Date         20241014
# Time        184721.00
# Lat.        23.726000
# Lon.       114.619003
# Dep.              0.1
# Mag.             8.88
# num                 0
# station          广东河源
# Name: 18680, dtype: object
# 4.833 8.343
# 18681 Date              20241014
# Time             212241.00
# Lat.             23.130800
# Lon.            117.352997
# Dep.                   0.6
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P2.2s)
# Name: 18681, dtype: object
# 45.701 80.943
# 18682 Date              20241014
# Time             232115.00
# Lat.             23.215099
# Lon.            117.380997
# Dep.                   0.4
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P1.7s)
# Name: 18682, dtype: object
# 45.741 81.011
# 18683 Date         20241015
# Time        030033.00
# Lat.        21.732000
# Lon.       111.802002
# Dep.              0.7
# Mag.            11.86
# num                 0
# station          广东阳江
# Name: 18683, dtype: object
# 52.698 93.528
# 18684 Date             20241015
# Time            030355.00
# Lat.            21.760900
# Lon.           111.752998
# Dep.                  0.2
# Mag.                -1.00
# num                     0
# station    广东阳江台(S-P2.8s)
# Name: 18684, dtype: object
# 52.961 93.992
# 18685 Date              20241015
# Time             041501.00
# Lat.             23.155399
# Lon.            117.136002
# Dep.                   0.6
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P2.5s)
# Name: 18685, dtype: object
# 42.974 76.039
# 18686 Date         20241015
# Time        050821.00
# Lat.        23.240999
# Lon.       117.209000
# Dep.              0.8
# Mag.            16.24
# num                 0
# station        广东南澳海域
# Name: 18686, dtype: object
# 43.496 76.982
# 18687 Date              20241015
# Time             072713.00
# Lat.             23.238600
# Lon.            117.454002
# Dep.                   0.4
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P2.4s)
# Name: 18687, dtype: object
# 46.551 82.468
# 18688 Date         20241015
# Time        103927.00
# Lat.        23.729000
# Lon.       114.617996
# Dep.              0.2
# Mag.             8.79
# num                 0
# station          广东河源
# Name: 18688, dtype: object
# 4.777 8.245
# 18689 Date         20241016
# Time        014705.00
# Lat.        23.737000
# Lon.       114.613998
# Dep.              0.2
# Mag.             6.50
# num                 0
# station          广东河源
# Name: 18689, dtype: object
# 4.612 7.961
# 18690 Date         20241016
# Time        140811.00
# Lat.        23.716000
# Lon.       114.644997
# Dep.              1.5
# Mag.             8.24
# num                 0
# station          广东河源
# Name: 18690, dtype: object
# 5.27 9.098
# 18691 Date         20241016
# Time        212907.00
# Lat.        23.304001
# Lon.       117.390999
# Dep.              0.6
# Mag.            14.90
# num                 0
# station        广东南澳海域
# Name: 18691, dtype: object
# 45.534 80.642
# 18692 Date         20241016
# Time        221316.00
# Lat.        21.746000
# Lon.       111.850998
# Dep.              1.2
# Mag.             9.55
# num                 0
# station          广东阳江
# Name: 18692, dtype: object
# 52.045 92.363
# 18693 Date         20241016
# Time        222733.00
# Lat.        21.712999
# Lon.       111.764000
# Dep.              1.0
# Mag.             4.73
# num                 0
# station          广东阳西
# Name: 18693, dtype: object
# 53.198 94.432
# 18694 Date         20241016
# Time        231746.00
# Lat.        21.719999
# Lon.       111.750000
# Dep.              1.0
# Mag.            12.08
# num                 0
# station          广东阳西
# Name: 18694, dtype: object
# 53.267 94.556
# 18695 Date         20241017
# Time        004523.00
# Lat.        21.747000
# Lon.       111.852997
# Dep.              1.5
# Mag.             9.73
# num                 0
# station          广东阳江
# Name: 18695, dtype: object
# 51.981 92.253
# 18696 Date             20241017
# Time            010137.00
# Lat.            21.757200
# Lon.           111.818001
# Dep.                  0.0
# Mag.                -1.00
# num                     0
# station    广东阳江台(S-P2.2s)
# Name: 18696, dtype: object
# 52.398 92.975
# 18697 Date         20241017
# Time        010837.00
# Lat.        23.302999
# Lon.       117.403999
# Dep.              0.3
# Mag.            14.67
# num                 0
# station        广东南澳海域
# Name: 18697, dtype: object
# 45.733 80.995
# 18698 Date             20241017
# Time            014548.00
# Lat.            21.749500
# Lon.           111.818001
# Dep.                  0.0
# Mag.                -1.00
# num                     0
# station    广东阳江台(S-P2.2s)
# Name: 18698, dtype: object
# 52.469 93.103
# 18699 Date              20241017
# Time             060539.00
# Lat.             23.110701
# Lon.            117.211998
# Dep.                   0.2
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P2.4s)
# Name: 18699, dtype: object
# 44.13 78.11
# 18700 Date         20241017
# Time        090844.00
# Lat.        21.745001
# Lon.       111.861000
# Dep.              1.3
# Mag.             4.93
# num                 0
# station          广东阳江
# Name: 18700, dtype: object
# 51.948 92.19
# 18701 Date         20241017
# Time        122742.00
# Lat.        23.709000
# Lon.       114.723999
# Dep.              0.2
# Mag.             7.63
# num                 0
# station          广东紫金
# Name: 18701, dtype: object
# 6.324 10.916
# 18702 Date         20241017
# Time        154437.00
# Lat.        23.308001
# Lon.       117.380997
# Dep.              1.5
# Mag.            15.79
# num                 0
# station        广东南澳海域
# Name: 18702, dtype: object
# 45.289 80.219
# 18703 Date              20241017
# Time             165908.00
# Lat.             23.272900
# Lon.            117.119003
# Dep.                   0.1
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P2.3s)
# Name: 18703, dtype: object
# 42.364 74.932
# 18704 Date              20241017
# Time             180035.00
# Lat.             23.422199
# Lon.            117.220001
# Dep.                   0.6
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P2.5s)
# Name: 18704, dtype: object
# 43.063 76.199
# 18705 Date              20241017
# Time             181817.00
# Lat.             23.112400
# Lon.            117.323997
# Dep.                   0.7
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P2.3s)
# Name: 18705, dtype: object
# 45.414 80.428
# 18706 Date              20241017
# Time             192614.00
# Lat.             23.395000
# Lon.            117.271004
# Dep.                   0.4
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P2.1s)
# Name: 18706, dtype: object
# 43.797 77.515
# 18707 Date         20241017
# Time        192744.00
# Lat.        23.320999
# Lon.       117.396004
# Dep.              1.0
# Mag.            16.33
# num                 0
# station        广东南澳海域
# Name: 18707, dtype: object
# 45.493 80.576
# 18708 Date              20241017
# Time             222906.00
# Lat.             23.145700
# Lon.            117.311996
# Dep.                   0.1
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P1.9s)
# Name: 18708, dtype: object
# 45.204 80.039
# 18709 Date         20241018
# Time        005451.00
# Lat.        23.743000
# Lon.       114.689003
# Dep.              1.5
# Mag.            10.28
# num                 0
# station          广东河源
# Name: 18709, dtype: object
# 5.437 9.385
# 18710 Date         20241018
# Time        010756.00
# Lat.        23.747000
# Lon.       114.635002
# Dep.              0.8
# Mag.             8.69
# num                 0
# station          广东河源
# Name: 18710, dtype: object
# 4.701 8.115
# 18711 Date         20241018
# Time        031309.00
# Lat.        23.747000
# Lon.       114.635002
# Dep.              0.7
# Mag.             8.58
# num                 0
# station          广东河源
# Name: 18711, dtype: object
# 4.7 8.114
# 18712 Date         20241018
# Time        081851.00
# Lat.        23.745001
# Lon.       114.635002
# Dep.              0.6
# Mag.             8.97
# num                 0
# station          广东河源
# Name: 18712, dtype: object
# 4.729 8.163
# 18713 Date              20241018
# Time             085306.00
# Lat.             23.376301
# Lon.            117.418999
# Dep.                   0.4
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P2.5s)
# Name: 18713, dtype: object
# 45.683 80.907
# 18714 Date              20241018
# Time             120342.00
# Lat.             23.295900
# Lon.            117.408997
# Dep.                   0.1
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P2.0s)
# Name: 18714, dtype: object
# 45.841 81.187
# 18715 Date         20241018
# Time        175102.00
# Lat.        23.742001
# Lon.       114.692001
# Dep.              0.2
# Mag.            10.77
# num                 0
# station          广东河源
# Name: 18715, dtype: object
# 5.484 9.466
# 18716 Date              20241018
# Time             192413.00
# Lat.             23.329000
# Lon.            117.427002
# Dep.                   0.5
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P2.3s)
# Name: 18716, dtype: object
# 45.911 81.318
# 18717 Date         20241018
# Time        233736.00
# Lat.        22.438000
# Lon.       116.820999
# Dep.              2.4
# Mag.            11.23
# num                 0
# station            南海
# Name: 18717, dtype: object
# 43.545 77.098
# 18718 Date         20241019
# Time        022008.00
# Lat.        22.448999
# Lon.       116.811996
# Dep.              1.2
# Mag.            13.15
# num                 0
# station            南海
# Name: 18718, dtype: object
# 43.509 77.011
# 18719 Date              20241019
# Time             034706.00
# Lat.             23.352501
# Lon.            117.320000
# Dep.                   0.0
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P1.7s)
# Name: 18719, dtype: object
# 44.577 78.911
# 18720 Date             20241019
# Time            051809.00
# Lat.            21.764400
# Lon.           111.724998
# Dep.                  0.1
# Mag.                -1.00
# num                     0
# station    广东阳江台(S-P3.0s)
# Name: 18720, dtype: object
# 53.212 94.44
# 18721 Date              20241019
# Time             064103.00
# Lat.             23.276899
# Lon.            117.289001
# Dep.                   0.3
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P1.2s)
# Name: 18721, dtype: object
# 44.406 78.609
# 18722 Date              20241019
# Time             080854.00
# Lat.             23.257999
# Lon.            117.306999
# Dep.                   0.2
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P1.2s)
# Name: 18722, dtype: object
# 44.705 79.145
# 18723 Date              20241019
# Time             085249.00
# Lat.             23.314100
# Lon.            117.392998
# Dep.                   0.2
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P1.9s)
# Name: 18723, dtype: object
# 45.574 80.707
# 18724 Date         20241019
# Time        235552.00
# Lat.        23.287001
# Lon.       117.380997
# Dep.              0.7
# Mag.            14.20
# num                 0
# station        广东南澳海域
# Name: 18724, dtype: object
# 45.454 80.501
# 18725 Date         20241019
# Time        235920.00
# Lat.        23.291000
# Lon.       117.379997
# Dep.              0.6
# Mag.            12.98
# num                 0
# station        广东南澳海域
# Name: 18725, dtype: object
# 45.441 80.475
# 18726 Date         20241020
# Time        032132.00
# Lat.        23.302000
# Lon.       117.315002
# Dep.              0.8
# Mag.             9.95
# num                 0
# station        广东南澳海域
# Name: 18726, dtype: object
# 44.581 78.932
# 18727 Date         20241020
# Time        054628.00
# Lat.        23.198000
# Lon.       117.271004
# Dep.              1.1
# Mag.             9.27
# num                 0
# station        广东南澳海域
# Name: 18727, dtype: object
# 44.379 78.575
# 18728 Date         20241020
# Time        084623.00
# Lat.        21.004999
# Lon.       110.745003
# Dep.              1.6
# Mag.            11.27
# num                 0
# station        广东湛江海域
# Name: 18728, dtype: object
# 69.363 123.508
# 18729 Date         20241020
# Time        092523.00
# Lat.        21.007999
# Lon.       110.745003
# Dep.              1.3
# Mag.            11.12
# num                 0
# station        广东湛江海域
# Name: 18729, dtype: object
# 69.372 123.518
# 18730 Date         20241020
# Time        122645.00
# Lat.        23.306000
# Lon.       117.374001
# Dep.              0.5
# Mag.            15.48
# num                 0
# station        广东南澳海域
# Name: 18730, dtype: object
# 45.33 80.274
# 18731 Date         20241020
# Time        155710.00
# Lat.        23.750999
# Lon.       114.630997
# Dep.              0.6
# Mag.            10.21
# num                 0
# station          广东河源
# Name: 18731, dtype: object
# 4.596 7.934
# 18732 Date         20241020
# Time        162930.00
# Lat.        23.753000
# Lon.       114.630997
# Dep.              0.7
# Mag.            10.31
# num                 0
# station          广东河源
# Name: 18732, dtype: object
# 4.568 7.885
# 18733 Date         20241020
# Time        164041.00
# Lat.        23.757999
# Lon.       114.633003
# Dep.              1.5
# Mag.             9.76
# num                 0
# station          广东河源
# Name: 18733, dtype: object
# 4.527 7.815
# 18734 Date         20241020
# Time        164052.00
# Lat.        23.750000
# Lon.       114.632004
# Dep.              0.7
# Mag.             9.88
# num                 0
# station          广东河源
# Name: 18734, dtype: object
# 4.623 7.979
# 18735 Date         20241020
# Time        164505.00
# Lat.        23.750000
# Lon.       114.628998
# Dep.              0.8
# Mag.            10.11
# num                 0
# station          广东河源
# Name: 18735, dtype: object
# 4.588 7.919
# 18736 Date         20241020
# Time        164824.00
# Lat.        23.750999
# Lon.       114.625999
# Dep.              0.6
# Mag.            10.14
# num                 0
# station          广东河源
# Name: 18736, dtype: object
# 4.538 7.833
# 18737 Date         20241020
# Time        164854.00
# Lat.        23.761999
# Lon.       114.638000
# Dep.              1.3
# Mag.             9.48
# num                 0
# station          广东河源
# Name: 18737, dtype: object
# 4.532 7.823
# 18738 Date         20241020
# Time        164802.00
# Lat.        23.757999
# Lon.       114.628998
# Dep.              0.4
# Mag.            10.07
# num                 0
# station          广东河源
# Name: 18738, dtype: object
# 4.473 7.721
# 18739 Date         20241020
# Time        165701.00
# Lat.        23.754999
# Lon.       114.632004
# Dep.              0.6
# Mag.             9.84
# num                 0
# station          广东河源
# Name: 18739, dtype: object
# 4.552 7.857
# 18740 Date         20241020
# Time        170019.00
# Lat.        23.750999
# Lon.       114.630997
# Dep.              0.1
# Mag.            10.06
# num                 0
# station          广东河源
# Name: 18740, dtype: object
# 4.595 7.932
# 18741 Date         20241020
# Time        170805.00
# Lat.        23.749001
# Lon.       114.632004
# Dep.              0.0
# Mag.            10.22
# num                 0
# station          广东河源
# Name: 18741, dtype: object
# 4.636 8.002
# 18742 Date         20241020
# Time        171047.00
# Lat.        23.754999
# Lon.       114.632004
# Dep.              0.1
# Mag.             9.79
# num                 0
# station          广东河源
# Name: 18742, dtype: object
# 4.55 7.855
# 18743 Date         20241020
# Time        174041.00
# Lat.        23.759001
# Lon.       114.625999
# Dep.              0.4
# Mag.             9.86
# num                 0
# station          广东河源
# Name: 18743, dtype: object
# 4.423 7.635
# 18744 Date         20241020
# Time        174041.00
# Lat.        22.437000
# Lon.       116.830002
# Dep.              1.5
# Mag.            12.44
# num                 0
# station            南海
# Name: 18744, dtype: object
# 43.755 77.46
# 18745 Date         20241020
# Time        190702.00
# Lat.        23.760000
# Lon.       114.632004
# Dep.              0.1
# Mag.             9.75
# num                 0
# station          广东河源
# Name: 18745, dtype: object
# 4.481 7.735
# 18746 Date         20241020
# Time        191511.00
# Lat.        23.761000
# Lon.       114.630997
# Dep.              0.5
# Mag.            10.10
# num                 0
# station          广东河源
# Name: 18746, dtype: object
# 4.455 7.691
# 18747 Date         20241020
# Time        191514.00
# Lat.        23.759001
# Lon.       114.635002
# Dep.              0.7
# Mag.             9.90
# num                 0
# station          广东河源
# Name: 18747, dtype: object
# 4.532 7.824
# 18748 Date         20241020
# Time        191605.00
# Lat.        23.754000
# Lon.       114.633003
# Dep.              0.2
# Mag.             9.80
# num                 0
# station          广东河源
# Name: 18748, dtype: object
# 4.577 7.9
# 18749 Date         20241020
# Time        192856.00
# Lat.        23.757999
# Lon.       114.633003
# Dep.              0.5
# Mag.            10.10
# num                 0
# station          广东河源
# Name: 18749, dtype: object
# 4.521 7.805
# 18750 Date         20241020
# Time        201246.00
# Lat.        23.679001
# Lon.       114.651001
# Dep.              0.2
# Mag.             8.04
# num                 0
# station          广东河源
# Name: 18750, dtype: object
# 5.892 10.171
# 18751 Date         20241020
# Time        201945.00
# Lat.        23.681000
# Lon.       114.652000
# Dep.              0.3
# Mag.             8.09
# num                 0
# station          广东河源
# Name: 18751, dtype: object
# 5.871 10.135
# 18752 Date         20241020
# Time        220946.00
# Lat.        24.756001
# Lon.       113.161003
# Dep.              0.8
# Mag.             4.04
# num                 0
# station          广东乳源
# Name: 18752, dtype: object
# 27.271 47.753
# 18753 Date              20241021
# Time             063456.00
# Lat.             23.202101
# Lon.            117.141998
# Dep.                   1.1
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P1.9s)
# Name: 18753, dtype: object
# 42.795 75.726
# 18754 Date              20241021
# Time             091506.00
# Lat.             23.122801
# Lon.            117.232002
# Dep.                   0.3
# Mag.                 -1.00
# num                      0
# station    广东南澎岛台(S-P2.2s)
# Name: 18754, dtype: object
# 44.307 78.431
